# %% [markdown]
# # 目的
# 以下を計算する
# - 外部データセットのラベル数

# %%
import polars as pl
import matplotlib.pyplot as plt
import ast

import itertools
from collections import Counter

# %%
train = pl.read_json("../data/train.json")
pii_dataset = pl.read_csv("../data/external_pii_dataset.csv")
pii_dataset_fixed = pl.read_csv("../data/pii_dataset_fixed.csv")
moredata_dataset_fixed = pl.read_csv("../data/moredata_dataset_fixed.csv")

# %%
pii_dataset = pii_dataset.with_columns(
    pl.col("tokens").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("trailing_whitespace").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("labels").map_elements(lambda x: ast.literal_eval(x)),
)

# %%
pii_dataset_fixed = pii_dataset_fixed.with_columns(
    pl.col("tokens").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("trailing_whitespace").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("labels").map_elements(lambda x: ast.literal_eval(x)),
)

# %%
moredata_dataset_fixed = moredata_dataset_fixed.with_columns(
    pl.col("tokens").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("trailing_whitespace").map_elements(lambda x: ast.literal_eval(x)),
    pl.col("labels").map_elements(lambda x: ast.literal_eval(x)),
)

# %% [markdown]
# # Visualization

# %%
import spacy
from spacy.tokens import Span, Doc
from spacy import displacy

# https://matplotlib.org/2.0.2/examples/color/named_colors.html
options = {
    "colors": {
        "B-NAME_STUDENT": "aqua",
        "I-NAME_STUDENT": "aliceblue",
        "B-EMAIL": "forestgreen",
        "I-EMAIL": "greenyellow",
        "B-USERNAME": "hotpink",
        "I-USERNAME": "lightpink",
        "B-ID_NUM": "purple",
        "I-ID_NUM": "rebeccapurple",
        "B-PHONE_NUM": "red",
        "I-PHONE_NUM": "salmon",
        "B-URL_PERSONAL": "slategrey",
        "I-URL_PERSONAL": "silver",
        "B-STREET_ADDRESS": "brown",
        "I-STREET_ADDRESS": "chocolate",
    }
}


class PiiLabelRenderer:
    def __init__(
        self,
        documents: list[str],
        tokens: list[str],
        labels: list[str],
        options: dict[str, dict[str, str]],
    ) -> None:
        self.documents = documents
        self.tokens = tokens
        self.labels = labels
        self.options = options
        self.nlp = spacy.blank("en")

    def render(
        self, render_idx: int | None = None, documents_id: int | None = None
    ) -> None:
        if render_idx and documents_id:
            raise Exception("Don't Use Both render_idx and documents_id")
        if documents_id:
            render_idx = self.documents.index(documents_id)

        doc = Doc(self.nlp.vocab, words=self.tokens[render_idx])
        # エンティティをDocに追加
        ents = []
        label_seq: list[str] = self.labels[render_idx]
        for i, label in enumerate(label_seq):
            if label == "O":
                continue
            ents.append(Span(doc, start=i, end=i + 1, label=label))

        doc.ents = ents

        displacy.render(doc, style="ent", jupyter=True, options=options)

# %%
# documents = pii_dataset_fixed.get_column("document").to_list()
# tokens = pii_dataset_fixed.get_column("tokens").to_list()
# full_texts = pii_dataset_fixed.get_column("text").to_list()
# labels = pii_dataset_fixed.get_column("labels").to_list()

documents = moredata_dataset_fixed.get_column("document").to_list()
tokens = moredata_dataset_fixed.get_column("tokens").to_list()
full_texts = moredata_dataset_fixed.get_column("text").to_list()
labels = moredata_dataset_fixed.get_column("labels").to_list()

# %%
PLR = PiiLabelRenderer(
    documents=documents, tokens=tokens, labels=labels, options=options
)

# %%
PLR.render(documents_id="pj_1844")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samantha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: aliceblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lynch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME_STUDENT</span>
# </mark>
#  : A Journey of Growth and Success <br><br> As I sit down to reflect on my academic journey , I am reminded of the countless experiences and opportunities that have shaped me into the person I am today . My name is
# <mark class="entity" style="background: aqua; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samantha
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME_STUDENT</span>
# </mark>
#
# <mark class="entity" style="background: aliceblue; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lynch
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME_STUDENT</span>
# </mark>
#  , and I am proud to share my story with you . <br><br> From the very beginning , my passion for learning and personal growth has been a driving force in my life . It is this drive that led me to pursue higher education and embark on a path of knowledge and discovery . Throughout my academic journey , I have encountered numerous challenges and triumphs , each of which has contributed to my growth as a student and as an individual . <br><br> One of the key aspects of my journey has been the connections I have made with others . Whether it be through my email address ,
# <mark class="entity" style="background: forestgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     benjaminconway@hotmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#  , or my username ,
# <mark class="entity" style="background: hotpink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mcarter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-USERNAME</span>
# </mark>
#  , on various platforms , I have always sought to engage with others who share my passion for learning . These connections have not only provided me with valuable insights and perspectives but have also allowed me to contribute to the academic community in meaningful ways . <br><br> In addition to my online presence , my personal identification number ,
# <mark class="entity" style="background: purple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     064
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ID_NUM</span>
# </mark>
#
# <mark class="entity" style="background: rebeccapurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ID_NUM</span>
# </mark>
#
# <mark class="entity" style="background: rebeccapurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     83
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ID_NUM</span>
# </mark>
#
# <mark class="entity" style="background: rebeccapurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ID_NUM</span>
# </mark>
#
# <mark class="entity" style="background: rebeccapurple; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1902
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ID_NUM</span>
# </mark>
#  , has been a constant reminder of my commitment to my education . This unique identifier has served as a reminder of the hard work and dedication I have put into my studies , and it has motivated me to strive for excellence in all that I do . <br><br> Furthermore , my phone number ,
# <mark class="entity" style="background: red; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     501
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE_NUM</span>
# </mark>
#
# <mark class="entity" style="background: salmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PHONE_NUM</span>
# </mark>
#
# <mark class="entity" style="background: salmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     733
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PHONE_NUM</span>
# </mark>
#
# <mark class="entity" style="background: salmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PHONE_NUM</span>
# </mark>
#
# <mark class="entity" style="background: salmon; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2718x551
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PHONE_NUM</span>
# </mark>
#  , has been a lifeline throughout my academic journey . Whether it be connecting with professors , classmates , or participating in group projects , my phone has been an essential tool for communication and collaboration . It has allowed me to stay connected and engaged , even when faced with the challenges of distance learning . <br><br> As I reflect on my journey , I am also reminded of the importance of embracing technology and utilizing online platforms . My personal URL ,
# <mark class="entity" style="background: slategrey; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     https://youtube.com/c/christopher17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-URL_PERSONAL</span>
# </mark>
#  , and my LinkedIn profile ,
# <mark class="entity" style="background: slategrey; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     https://linkedin.com/in/robinsonkelsey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-URL_PERSONAL</span>
# </mark>
#  , have been instrumental in showcasing my skills and accomplishments . These platforms have allowed me to connect with professionals in my field , explore new opportunities , and share my knowledge with a wider audience . <br><br> Lastly , my street addresses ,
# <mark class="entity" style="background: brown; padding: 0.4
